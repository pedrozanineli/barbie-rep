# %% [markdown]
# ### Data Load

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
from utils.funcs import *

# %% [markdown]
# ### Proteins Comparision

# %%
wls_cbm, cd_abs_cbm, error_cbm = cdproc(3,'CD_data/08-05-24')
wls_b1, cd_abs_b1, error_b1 = cdproc(4,'CD_data/08-05-24')

# %%
cdplot(wls_b1,cd_abs_b1,'BARBIE1','#E0218A')
cdplot(wls_cbm,cd_abs_cbm,'BaCBM2','#477081')

# Sem normalização
plt.xlim(200,250), plt.ylim(-15,10)
plt.grid(), plt.tight_layout()

plt.show()

# %% [markdown]
# ### Heating Ramp

# %%
wls_b1, temp_b1, cd_abs_b1, error_b1 = rampproc('CD_data/B1-CBM-ramp',25,1,96)
wls_cbm, temp_cbm, cd_abs_cbm, error_cbm = rampproc('CD_data/BaCBM2-ramp',25,1,96)

# %%
rampplot(wls_b1, temp_b1, cd_abs_b1)
rampplot(wls_cbm, temp_cbm, cd_abs_cbm)
# Out:
# <Axes3DSubplot: xlabel='Wavelength (nm)', ylabel='Temperature (ºC)', zlabel='CD Absorbance (millidegrees)'>

# %% [markdown]
# ### Pontual Spectra

# %% [markdown]
# ### Plastic Interaction

# %% [markdown]
# ### Denaturation-Renaturation

# %%
wls_b1_heat, temp_b1_heat, cd_abs_b1_heat, error_b1_heat = rampproc('CD_data/rampa B1_05_09',25,1,96)

# %%
ax = rampplot(wls_b1_heat,temp_b1_heat,cd_abs_b1_heat)
plt.show()

# %%
wlspectra(210,wls_b1_heat,temp_b1_heat,cd_abs_b1_heat,error_b1_heat)
plt.grid(),plt.tight_layout()
plt.show()
# Out:
# c:\Users\pedro220068\Documents\iGEM\barbie-rep\3_experimental-analysis\utils\funcs.py:66: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "r--o" (-> color='r'). The keyword argument will take precedence.
#   plt.errorbar(temperaturas,wl_cd,yerr=error,capsize=3,fmt="r--o",color="#E0218A",ecolor = "black")
