# %% [markdown]
# Calculated distance between TRP8:CA and STYRS10:C7
#
# `2` in keyboard > atom selection, `Graphics` > `Labels` > `Bonds`
#
# Styrene tag: `resname STYRR`
#
# Further analysis: expand to RMSD - couldn't select atoms (both protein and resname STYRR)

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
from matplotlib import font_manager

font_path = '../Ruda/Ruda-VariableFont_wght.ttf'
font_manager.fontManager.addfont(font_path)
prop = font_manager.FontProperties(fname=font_path)

plt.rcParams['font.family'] = 'sans-serif'
plt.rcParams['font.sans-serif'] = prop.get_name()

# %% [markdown]
# #### Distance CBM x PS

# %%
cbm = pd.read_csv('data/b1_x_cbm/distances_cbm-ps.dat',sep='\t',names=['Frame','Distance'])
b1_10xps = pd.read_csv('data/b1_x_cbm/distances_b1-ps.dat',sep='\t',names=['Frame','Distance'])

# %%
plt.plot(b1_10xps['Frame'],b1_10xps['Distance'],label='b1')
plt.plot(cbm['Frame'],cbm['Distance'],label='cbm')

plt.xlim(min(b1_10xps['Frame']),max(b1_10xps['Frame']))
plt.gca().spines['top'].set_visible(False)
plt.gca().spines['right'].set_visible(False)

plt.xlabel('Frame')
plt.ylabel('Distance (Å)')

plt.grid()
plt.legend()

plt.show()

# %% [markdown]
# #### RMSD PS

# %%
rmsd_ps_b1 = pd.read_csv('data/b1_x_cbm/ps_rmsd-barbie1_ps.dat',sep='\t',names=['ref_mol','ref_frame','mol','frame','rmsd'],skiprows=1)
rmsd_ps_cbm = pd.read_csv('data/b1_x_cbm/ps_rmsd-cbm_ps.dat',sep='\t',names=['ref_mol','ref_frame','mol','frame','rmsd'],skiprows=1)

# %%
plt.plot(rmsd_ps_b1['frame'].iloc[:681],rmsd_ps_b1['rmsd'].iloc[:681],marker='.',label='Barbie1')
plt.plot(rmsd_ps_cbm['frame'].iloc[:681],rmsd_ps_cbm['rmsd'].iloc[:681],marker='.',label='BaCBM2')

plt.xlabel('Frame',fontsize=14),plt.ylabel('RMSD',fontsize=14)
plt.grid(),plt.legend(),plt.tight_layout()
# plt.savefig('results/ps_RMSD.png',dpi=300)
plt.show()
